# %% [markdown]
# # Python implementations of the pseudocode in Algorithms Illuminated by Tim Roughgarden (Introduction)

# %% [markdown]
# ## Standard School Multiplication

# %%
def standard_multiplication(x,y):

    result = 0
    
    for i in range(len(str(y))):
        current_y_digit = y//10**i%10
        addition_row = []
        for j in range(len(str(x))):
            current_x_digit = x//10**j%10
            addition_row_counter = -j-1

            if len(addition_row) < -addition_row_counter:

                if(current_x_digit*current_y_digit)<10:
                    addition_row.insert(addition_row_counter, current_x_digit*current_y_digit)
                elif(current_x_digit*current_y_digit)>=10:
                    addition_row.insert(addition_row_counter, current_x_digit*current_y_digit%10)
                    addition_row.insert(addition_row_counter-1,current_x_digit*current_y_digit//10)

            else:
                if current_x_digit*current_y_digit >= 10:
                    upd_value_cur_counter = current_x_digit*current_y_digit%10+addition_row[addition_row_counter]
                    if upd_value_cur_counter >= 10:
                        addition_row[addition_row_counter] = upd_value_cur_counter%10
                        addition_row.insert(addition_row_counter,upd_value_cur_counter//10+current_x_digit*current_y_digit//10)
                    else:
                        addition_row[addition_row_counter] = upd_value_cur_counter
                        addition_row.insert(addition_row_counter,current_x_digit*current_y_digit//10)
                else:
                    upd_value_cur_counter = current_x_digit*current_y_digit+addition_row[addition_row_counter]
                    if upd_value_cur_counter >= 10:
                        addition_row[addition_row_counter] = upd_value_cur_counter%10
                        addition_row.insert(addition_row_counter,upd_value_cur_counter//10)
                    else:
                        addition_row[addition_row_counter] = upd_value_cur_counter


        result += int("".join(map(str, addition_row)))*10**i

    return result

# %% [markdown]
# ## Recursive Multiplication

# %%
def recursive_multiplication(x,y):

    n = len(str(x))
    
    if n == 1:
        return x*y
    else:
        divider_x = 10**(n//2)
        divider_y = 10**(n//2)
        a = x // divider_x
        b = x % divider_x
        c = y // divider_y
        d = y % divider_y

        ac=recursive_multiplication(a,c)
        ad=recursive_multiplication(a,d)
        bc=recursive_multiplication(b,c)
        bd=recursive_multiplication(b,d)        

        return 10**(2*(n//2))*ac+10**(n//2)*(ad+bc)+bd

# %% [markdown]
# ## Karatsuba Multiplication

# %%
def karatsuba_multiplication(x,y):

    n = len(str(x))

    if n == 1:
        return x*y
    else:
        divider_x = 10**(n//2)
        divider_y = 10**(n//2)

        a = x // divider_x
        b = x % divider_x
        c = y // divider_y
        d = y % divider_y
        p = a + b
        q = c + d

        ac=recursive_multiplication(a,c)
        bd=recursive_multiplication(b,d)
        pq = recursive_multiplication(p,q)

        sum_ad_bc = pq-ac-bd
        return 10**(2*(n//2))*ac+10**(n/2)*sum_ad_bc+bd

# %% [markdown]
# ### Validity tests

# %%
import random 

for i in range(1000):
    x,y = random.randint(0, 999999), random.randint(0, 999999)
    assert standard_multiplication(x,y)==x*y, (x,y)

    n = random.choice([2,4,6])
    x,y = random.randint(10**(n-1), 10**n-1), random.randint(10**(n-1), 10**n -1)
    assert recursive_multiplication(x,y)==x*y, (x,y)
    assert karatsuba_multiplication(x,y)==x*y, (x,y)
print("Test complete")
# Out:
# Test complete

# %% [markdown]
# ### Time tests

# %%
# %timeit standard_multiplication(5678,1234)
# %timeit recursive_multiplication(5678,1234)
# %timeit karatsuba_multiplication(5678,1234)
# %timeit 5678*1234 # python uses native cpu multiplication and karatsuba multiplication method written on C for big integers
# Out:
# 3.98 μs ± 23.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 1.69 μs ± 11.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 2.08 μs ± 8.49 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 2.92 ns ± 0.00436 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %% [markdown]
# ## MergeSort

# %%
def mergesort(arr): 
    if len(arr) <= 1:
        return arr
    else:
        first_arr = mergesort(arr[0:len(arr)//2])
        second_arr = mergesort(arr[len(arr)//2:len(arr)])
        arr = merge(first_arr, second_arr)
    return arr

def merge(first_arr, second_arr):
    i,j=0,0
    output_arr=[] 
    while i < len(first_arr) and j < len(second_arr):
        if first_arr[i] < second_arr[j]:
            output_arr.append(first_arr[i])
            i+=1
        else:
            output_arr.append(second_arr[j])
            j+=1
    output_arr.extend(first_arr[i:])
    output_arr.extend(second_arr[j:])
    return output_arr

# %%
import random 

check_index = 0
for i in range(0,9999):
    n = random.randint(0,999)
    array = random.sample(range(0, 9999), n)
    if check_index < 3:
        print(f"Array size: {n}. Array: {array}")
        check_index += 1
    assert mergesort(array) == sorted(array), array
# Out:
# Array size: 435. Array: [3510, 4029, 4551, 4150, 7173, 9409, 2048, 6363, 3196, 8196, 449, 901, 3947, 5657, 7176, 9585, 6232, 1894, 830, 3216, 435, 5248, 4112, 1977, 7207, 3121, 6615, 2648, 935, 4085, 2522, 5785, 433, 7660, 9378, 6436, 4012, 5766, 1783, 4230, 8649, 5097, 7267, 8743, 2173, 635, 5970, 3702, 2542, 8555, 3622, 869, 2969, 2238, 2086, 1130, 986, 512, 7724, 9844, 9296, 332, 9636, 4349, 5080, 787, 3497, 6824, 7023, 8175, 1774, 2883, 584, 4351, 8568, 7557, 9808, 6774, 2724, 8359, 8634, 1401, 888, 1147, 9188, 9854, 4388, 3239, 7718, 1024, 8182, 1855, 9276, 2301, 8915, 2836, 6405, 8408, 1842, 9066, 9309, 9689, 5401, 8472, 969, 2390, 9768, 3469, 5557, 691, 9486, 753, 8784, 964, 7454, 1834, 738, 5170, 5377, 3860, 4663, 9957, 7938, 7187, 9047, 2933, 2502, 4653, 6034, 9208, 3488, 1448, 7889, 3586, 9256, 6796, 242, 1153, 7760, 6399, 6907, 399, 3569, 7488, 8872, 9668, 8700, 8033, 8417, 741, 6368, 4572, 347, 7504, 2201, 8469, 8863, 8610, 3422, 1150, 6237, 1084, 8792, 1621, 7208, 2288, 3696, 6621, 2674, 3661, 9751, 758, 6494, 6843, 3624, 1032, 7814, 2347, 178, 1099, 9827, 9733, 459, 647, 5747, 9313, 3909, 8721, 8254, 555, 9633, 8043, 9120, 3617, 2862, 3246, 3212, 6953, 6732, 5874, 4550, 6994, 364, 273, 2091, 6997, 5390, 9672, 2302, 1085, 6190, 182, 3835, 2849, 2964, 9265, 7109, 5977, 4142, 4515, 2823, 7213, 983, 1314, 5078, 1439, 8480, 3318, 2936, 9223, 8209, 8931, 1472, 8037, 3105, 2456, 5794, 5084, 3131, 2990, 5692, 214, 882, 2971, 2654, 6145, 5317, 5407, 6682, 1270, 9246, 2533, 448, 934, 4589, 4367, 6723, 4412, 8399, 6259, 5602, 5765, 3965, 2594, 4041, 2635, 382, 2007, 4723, 3160, 4709, 4244, 26, 7019, 6001, 69, 5210, 246, 1514, 7498, 6212, 1830, 9742, 9816, 7578, 8484, 1016, 3238, 5683, 4679, 2673, 4718, 4685, 3585, 8114, 4193, 739, 6788, 5555, 5336, 22, 9644, 5056, 6353, 9803, 6038, 7507, 2934, 1018, 2180, 8391, 6312, 8521, 1878, 1887, 4677, 8286, 681, 366, 9530, 6557, 7120, 6254, 6913, 9673, 4722, 7918, 5301, 827, 7832, 4162, 7346, 9272, 9055, 6228, 4397, 8333, 1148, 4261, 9478, 4818, 1306, 8757, 181, 2944, 1433, 4890, 9148, 7064, 9456, 1341, 6695, 7525, 9802, 8545, 706, 2081, 5163, 7584, 8560, 5232, 4415, 2894, 9859, 9929, 1338, 7265, 2401, 1751, 6548, 796, 4432, 1469, 6538, 5690, 1136, 9443, 7177, 4525, 23, 1963, 2728, 7922, 6157, 6895, 7821, 5349, 8079, 408, 2705, 9438, 3178, 6303, 4787, 378, 9424, 3521, 5626, 979, 2307, 8172, 7976, 682, 8120, 4336, 5762, 3360, 8041, 5513, 5481, 4234, 2686, 5190, 4940, 3164, 7603, 8813, 6355, 3306, 5768, 1630, 9028, 7036, 4182, 1373, 4666, 4343, 9479, 4060, 7549, 2963, 1121, 2437, 8491, 1591]
# Array size: 134. Array: [3647, 9341, 8543, 5567, 8487, 2208, 7084, 4586, 3552, 6015, 503, 2818, 6645, 8018, 1513, 7418, 6533, 9176, 4939, 5488, 979, 2573, 7108, 5886, 589, 2633, 8472, 3465, 8417, 6562, 4660, 9228, 5290, 5273, 2771, 1176, 7348, 9067, 3422, 5660, 2893, 8594, 2950, 9679, 4249, 4213, 3679, 2400, 1630, 5874, 4622, 3537, 862, 9315, 3310, 6631, 9282, 1355, 8813, 4494, 8308, 370, 5264, 2315, 7788, 7122, 4576, 899, 4737, 1383, 7854, 7518, 9232, 1151, 251, 1140, 6553, 263, 2090, 7520, 2246, 3079, 4466, 9050, 6650, 4463, 4952, 4596, 9954, 3028, 8448, 1902, 3377, 4738, 5996, 6687, 5442, 4987, 4364, 8927, 6430, 5490, 1576, 6314, 8358, 7468, 4699, 5404, 730, 9682, 3388, 8127, 7541, 9611, 2614, 4618, 6626, 2866, 2362, 5968, 9510, 7893, 9959, 8752, 2470, 8249, 6137, 5734, 2639, 7920, 9733, 971, 7787, 3218]
# Array size: 902. Array: [4239, 4551, 4822, 301, 183, 2629, 9648, 7474, 4380, 7637, 841, 7905, 6532, 1501, 7856, 3888, 4363, 5714, 9165, 2905, 6236, 497, 96, 637, 2708, 5190, 333, 2694, 1596, 498, 3058, 8029, 9054, 6226, 9620, 8653, 1173, 5173, 9575, 6150, 2929, 4527, 286, 19, 6114, 9326, 4589, 9711, 7276, 3328, 9043, 1583, 1955, 5297, 257, 9733, 1216, 4852, 5586, 9682, 6280, 7501, 6470, 7923, 5755, 7734, 9081, 1684, 3844, 6221, 9900, 6633, 2704, 9806, 1666, 5421, 4202, 4118, 1045, 1463, 5204, 3842, 5992, 6862, 1986, 2988, 1530, 7072, 9918, 1747, 9781, 7053, 8725, 4945, 7706, 944, 8204, 6806, 5408, 8940, 11, 2014, 8187, 2810, 4152, 3536, 6284, 5653, 6819, 9388, 9573, 7417, 5867, 4729, 5532, 241, 1646, 4385, 9505, 2128, 9905, 7177, 1880, 5213, 6392, 2495, 433, 2096, 6002, 1758, 2691, 9607, 2028, 5471, 8877, 6220, 2846, 3986, 3308, 7688, 6291, 626, 9030, 3717, 3342, 1952, 235, 8734, 6720, 8542, 8426, 5211, 8152, 5368, 4600, 4900, 9558, 4138, 8775, 2641, 7075, 7273, 4404, 7035, 706, 6276, 3880, 1023, 5806, 8463, 7034, 9463, 9491, 4097, 634, 271, 8919, 4255, 6191, 5409, 1126, 8443, 1022, 690, 2466, 903, 7197, 2862, 5695, 4459, 5165, 4880, 6053, 3113, 9394, 704, 6227, 394, 8297, 8139, 467, 8724, 7361, 4773, 674, 3901, 1933, 3077, 7083, 4273, 4744, 3238, 5751, 2493, 2972, 4089, 1038, 1740, 9590, 562, 9389, 1417, 2601, 7836, 8285, 4853, 3732, 7840, 3311, 1120, 5364, 6256, 1697, 4491, 5, 1353, 4328, 150, 2448, 5243, 6172, 9196, 736, 2392, 1198, 4070, 1079, 6851, 285, 6419, 5592, 8740, 2264, 5008, 7541, 1815, 8471, 4751, 9797, 9800, 5284, 7704, 9149, 8256, 2373, 5426, 5587, 3051, 1817, 8451, 6463, 6521, 2099, 4225, 992, 7886, 6346, 1734, 7885, 5829, 2325, 4286, 866, 3731, 9664, 6506, 6341, 7029, 448, 8108, 255, 9925, 1625, 5110, 9904, 3227, 1886, 1194, 9346, 3928, 9281, 585, 7708, 7315, 5203, 6713, 9208, 5150, 4386, 838, 398, 9077, 874, 5208, 9548, 3206, 4037, 581, 9188, 9445, 6714, 157, 8730, 1001, 1814, 4353, 1123, 8364, 9974, 5512, 2819, 5218, 2247, 5074, 8575, 7298, 208, 3624, 912, 5609, 3468, 5137, 3488, 3226, 1736, 1798, 1358, 7732, 9979, 4251, 4532, 1854, 1893, 2204, 1767, 1410, 2571, 7799, 8978, 2427, 7319, 6954, 5444, 1645, 8202, 8125, 434, 8409, 6245, 927, 4712, 3020, 3837, 5886, 3776, 9201, 3011, 2996, 2843, 9007, 3199, 5634, 3568, 5861, 213, 3528, 503, 3012, 907, 1102, 219, 7093, 7812, 6145, 8127, 4400, 7872, 1040, 8533, 8470, 5626, 3849, 2628, 3133, 7004, 786, 5826, 9719, 5740, 9956, 1227, 8258, 3040, 2211, 3066, 4716, 4377, 5809, 6077, 7173, 3303, 588, 9625, 7059, 491, 1116, 8850, 2771, 5383, 8666, 7001, 1486, 8780, 4396, 8140, 5050, 9181, 6271, 5495, 5700, 358, 6260, 8750, 317, 692, 4010, 6424, 9977, 397, 132, 8069, 1649, 5758, 2654, 4322, 2926, 4917, 6210, 6153, 2866, 206, 8509, 3761, 8205, 9510, 6895, 7229, 8092, 8525, 5271, 8921, 7827, 7064, 2535, 8487, 4426, 3914, 287, 9065, 2784, 4373, 1639, 1052, 7184, 9187, 419, 6511, 5214, 7208, 2517, 3430, 1985, 6575, 2781, 1142, 9442, 6850, 9317, 8433, 7403, 8389, 9050, 7227, 8667, 4544, 3824, 5045, 1803, 6320, 6350, 93, 9013, 3156, 2382, 2189, 9012, 8833, 3751, 2277, 4156, 3151, 6358, 2202, 1582, 9373, 947, 3169, 2804, 9842, 6257, 1914, 7446, 9987, 3931, 9488, 387, 4289, 911, 5335, 6790, 8333, 9602, 3070, 4376, 3534, 8496, 4029, 9154, 9672, 6323, 5679, 8114, 4005, 4977, 8111, 8419, 6689, 531, 8387, 9236, 7027, 8479, 1300, 2294, 1006, 1705, 791, 6097, 495, 2142, 7595, 8382, 5059, 9762, 9614, 7603, 920, 2632, 4640, 4223, 924, 9324, 7628, 2813, 7891, 1522, 3221, 266, 2983, 7020, 7200, 7283, 1089, 4854, 3936, 2868, 8468, 9214, 3840, 3492, 3809, 1131, 2260, 4770, 2171, 1129, 7181, 4745, 7084, 755, 4365, 8042, 8149, 8913, 6225, 1363, 5285, 7547, 472, 6064, 5978, 7842, 8065, 657, 1939, 9168, 289, 2798, 5152, 7080, 6898, 9885, 5040, 4260, 9059, 8174, 4030, 4572, 1055, 9434, 2806, 3780, 953, 383, 1827, 6548, 2945, 5615, 5794, 7026, 5194, 699, 4044, 7469, 5313, 2885, 6141, 3570, 6460, 8113, 5894, 4684, 4629, 2924, 4502, 7307, 3925, 1574, 740, 1917, 713, 3998, 9343, 9534, 4091, 308, 1379, ...

# %%
# %timeit mergesort([1,5,6,4])
# Out:
# 2.21 μs ± 5.51 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
