# %% [markdown]
# # Python implementations of the pseudocode in Algorithms Illuminated by Tim Roughgarden (Divide & Conquer Algorithms)

# %% [markdown]
# ## Brute Force Search for Counting Inversions - $O(n^2)$

# %%
def count_invers_brute_force(arr):
    invers_num = 0
    for i in range(len(arr)-1):
        for j in range(i+1, len(arr)):
            if arr[i] > arr[j]:
                invers_num += 1
    return invers_num

# %%
import big_o

gen = lambda n: (list(range(n, 0, -1)))

best, others = big_o.big_o(count_invers_brute_force, gen, n_repeats = 20, max_n = 800)

print(big_o.reports.big_o_report(best, others))
# Out:
# Best : Quadratic: time = -0.0042 + 6.3E-07*n^2 (sec)
# Constant: time = 0.15 (sec)                                     (res: 0.17)
# Linear: time = -0.099 + 0.00056*n (sec)                         (res: 0.0088)
# Quadratic: time = -0.0042 + 6.3E-07*n^2 (sec)                   (res: 4.8E-05)
# Cubic: time = 0.033 + 7.7E-10*n^3 (sec)                         (res: 0.0034)
# Polynomial: time = 5.8E-07 * x^2 (sec)                          (res: 0.00039)
# Logarithmic: time = -0.9 + 0.18*log(n) (sec)                    (res: 0.039)
# Linearithmic: time = -0.073 + 8.1E-05*n*log(n) (sec)            (res: 0.0063)
# Exponential: time = 0.0072 * 1^n (sec)                          (res: 0.048)

# %% [markdown]
# ## Counting Inversions in $O(n\log n)$ Time

# %%
def sort_count_inversions(arr):
    if len(arr) <= 1:
        return (arr, 0)
    else:
        mid = len(arr) // 2
        left_arr, left_count = sort_count_inversions(arr[:mid])
        right_arr, right_count = sort_count_inversions(arr[mid:])
        arr_inv, count_inv = merge_and_count(left_arr, right_arr)
        return (arr_inv, left_count+right_count+count_inv)
    
def merge_and_count(first_arr, second_arr):
    i, j, count_inv, output_arr = 0, 0, 0, []
    while i < len(first_arr) and j < len(second_arr):
        if first_arr[i] < second_arr[j]:
            output_arr.append(first_arr[i])
            i+=1
        else:
            output_arr.append(second_arr[j])
            j+=1
            count_inv = count_inv + len(first_arr) - i 
    output_arr.extend(first_arr[i:])
    output_arr.extend(second_arr[j:])
    return (output_arr, count_inv)

# %%
gen = lambda n: list(range(n,0,-1))

best, others = big_o.big_o(sort_count_inversions, gen, n_repeats = 20, max_n = 50000)

print(big_o.reports.big_o_report(best, others))
# Out:
# Best : Linearithmic: time = 0.054 + 3.7E-06*n*log(n) (sec)
# Constant: time = 1 (sec)                                        (res: 4.2)
# Linear: time = 0.0017 + 4.1E-05*n (sec)                         (res: 0.0099)
# Quadratic: time = 0.35 + 7.6E-10*n^2 (sec)                      (res: 0.25)
# Cubic: time = 0.51 + 1.5E-14*n^3 (sec)                          (res: 0.64)
# Polynomial: time = 3.3E-05 * x^1 (sec)                          (res: 0.013)
# Logarithmic: time = -1.7 + 0.29*log(n) (sec)                    (res: 1.7)
# Linearithmic: time = 0.054 + 3.7E-06*n*log(n) (sec)             (res: 0.0094)
# Exponential: time = 0.062 * 1^n (sec)                           (res: 9.1)

# %% [markdown]
# ## Strassen's Matrix Multiplication Algorithm

# %% [markdown]
# ### Brute force Approach - $O(n^3)$

# %%
def bruteforce_mat_mult(mat1, mat2):
    n = len(mat1)
    output_mat = [[0]*n for x in range(n)]
    for i in range(n):
        for j in range(n):
            output_mat[i][j] = 0
            for k in range(n):
                output_mat[i][j] = output_mat[i][j] + mat1[i][k]*mat2[k][j]
    return output_mat

# %%
import big_o, random

def make_mat(n):
    mat1 = [[random.randint(0, 9) for i in range(n)] for i in range(n)]
    mat2 = [[random.randint(0, 9) for i in range(n)] for i in range(n)]
    return (mat1, mat2)

best, others = big_o.big_o(lambda args: bruteforce_mat_mult(*args), make_mat, min_n=10, max_n=150, n_measures=10, n_repeats=5)
print(big_o.reports.big_o_report(best, others))
# Out:
# Best : Cubic: time = 0.0013 + 4.3E-07*n^3 (sec)
# Constant: time = 0.42 (sec)                                     (res: 2.2)
# Linear: time = -0.35 + 0.0098*n (sec)                           (res: 0.34)
# Quadratic: time = -0.11 + 6.4E-05*n^2 (sec)                     (res: 0.06)
# Cubic: time = 0.0013 + 4.3E-07*n^3 (sec)                        (res: 0.0003)
# Polynomial: time = 1E-06 * x^2.8 (sec)                          (res: 0.012)
# Logarithmic: time = -1.4 + 0.44*log(n) (sec)                    (res: 0.99)
# Linearithmic: time = -0.26 + 0.0019*n*log(n) (sec)              (res: 0.26)
# Exponential: time = 0.0025 * 1^n (sec)                          (res: 3.9)

# %% [markdown]
# ### Basic Recursive Approach

# %%
def rec_mat_mult(mat1, mat2):
    if len(mat1) and len(mat2) == 1:
        return mat1[1][1]*mat2[1][1]
    else: 
        mid = len(mat1) // 2
        a_mat1 = rec_mat_mult[mat1[:mid][:mid]]
        b_mat1 = rec_mat_mult[mat1[mid:][:mid]]
        c_mat1 = rec_mat_mult[mat1[:mid][mid:]]
        d_mat1 = rec_mat_mult[mat1[mid:][mid:]]
        a_mat2 = rec_mat_mult[mat2[:mid][:mid]]
        b_mat2 = rec_mat_mult[mat2[mid:][:mid]]
        c_mat2 = rec_mat_mult[mat2[:mid][mid:]]
        d_mat2 = rec_mat_mult[mat2[mid:][mid:]]

        p1 = a_mat1*a_mat2
        p2 =
        p3 = 
        p4 = 
        p5 = 
        p6 = 
        p7 = 
        p8 = 

    return output_mat
